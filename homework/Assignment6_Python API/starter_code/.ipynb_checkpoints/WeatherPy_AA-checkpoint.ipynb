# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
import time 

# Import API key

from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#creating placeholder city list
#cities_fake = ['New York','Boston']
#print(cities_fake)

# %%
count = 1
sets = 1
url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + weather_api_key
citydata = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

for city in cities:
    city_url = url + "&q=" + city +"&units=" + "imperial"
    cityresponse = requests.get(city_url).json()    
    try:
        print(f'Processing Record {count} of Set {sets} | {city}')

        latitude = cityresponse["coord"]["lat"]
        maxtemp = cityresponse["main"]["temp_max"]
        humidity = cityresponse["main"]["humidity"]
        cloudiness = cityresponse["clouds"]["all"]
        windspeed = cityresponse["wind"]["speed"]
        citydata.append({"City": city,
                          "Latitude": latitude,
                          "Max Temp": maxtemp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": windspeed})
        
    except:
        print("City not found. Skipping...")
    count += 1
    if count == 51:
        sets += 1
        count = 0
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | okhotsk
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | stromness
# Processing Record 6 of Set 1 | paramonga
# Processing Record 7 of Set 1 | qixia
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | brejo santo
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | karratha
# Processing Record 16 of Set 1 | berdigestyakh
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | grand gaube
# Processing Record 19 of Set 1 | zemio
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | keelung
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | vao
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | fort nelson
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | coihaique
# Processing Record 38 of Set 1 | harper
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | brownsville
# Processing Record 41 of Set 1 | banda aceh
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | gat
# Processing Record 45 of Set 1 | griffith
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | trinidad
# Processing Record 48 of Set 1 | eureka
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 0 of Set 2 | puerto baquerizo moreno
# Processing Record 1 of Set 2 | san rafael del sur
# Processing Record 2 of Set 2 | kamenka
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | alta floresta
# Processing Record 9 of Set 2 | tautira
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | kysyl-syr
# Processing Record 12 of Set 2 | sao joao da barra
# Processing Record 13 of Set 2 | oktyabrskoye
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | sisimiut
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | coari
# Processing Record 19 of Set 2 | williams lake
# Processing Record 20 of Set 2 | nazret
# Processing Record 21 of Set 2 | amapa
# Processing Record 22 of Set 2 | yendi
# Processing Record 23 of Set 2 | ilulissat
# Processing Record 24 of Set 2 | mgandu
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | raudeberg
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | bela
# Processing Record 29 of Set 2 | karaj
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | annau
# Processing Record 33 of Set 2 | aktau
# Processing Record 34 of Set 2 | progreso
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | akdepe
# Processing Record 42 of Set 2 | tiznit
# Processing Record 43 of Set 2 | paamiut
# Processing Record 44 of Set 2 | sobolevo
# Processing Record 45 of Set 2 | felanitx
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | bayshore gardens
# Processing Record 48 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | yushu
# Processing Record 50 of Set 2 | didwana
# Processing Record 0 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 3 | wazzan
# City not found. Skipping...
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | polunochnoye
# Processing Record 4 of Set 3 | beirut
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | vila franca do campo
# Processing Record 8 of Set 3 | creel
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | padang
# Processing Record 11 of Set 3 | russell
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | valle hermoso
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | henties bay
# Processing Record 17 of Set 3 | khandbari
# Processing Record 18 of Set 3 | suluq
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | samarai
# Processing Record 22 of Set 3 | palmer
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | tual
# Processing Record 25 of Set 3 | erenhot
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | lerwick
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | chimore
# Processing Record 30 of Set 3 | gediz
# Processing Record 31 of Set 3 | dongsheng
# Processing Record 32 of Set 3 | manzhouli
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | kokstad
# Processing Record 36 of Set 3 | senador jose porfirio
# Processing Record 37 of Set 3 | puerto ayora
# Processing Record 38 of Set 3 | kaeo
# Processing Record 39 of Set 3 | seybaplaya
# Processing Record 40 of Set 3 | owando
# Processing Record 41 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 3 | coos bay
# Processing Record 43 of Set 3 | baykit
# Processing Record 44 of Set 3 | hobyo
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | san juan
# Processing Record 48 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | nadym
# Processing Record 0 of Set 4 | lebu
# Processing Record 1 of Set 4 | pyay
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | khilok
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | alofi
# Processing Record 8 of Set 4 | port alfred
# Processing Record 9 of Set 4 | borama
# City not found. Skipping...
# Processing Record 10 of Set 4 | sri aman
# Processing Record 11 of Set 4 | sola
# Processing Record 12 of Set 4 | otradnoye
# Processing Record 13 of Set 4 | mafeteng
# Processing Record 14 of Set 4 | soto la marina
# Processing Record 15 of Set 4 | iranshahr
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | yamada
# Processing Record 18 of Set 4 | sistranda
# Processing Record 19 of Set 4 | kautokeino
# Processing Record 20 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 4 | northam
# Processing Record 22 of Set 4 | husavik
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | cabra
# Processing Record 25 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 4 | zhangye
# Processing Record 27 of Set 4 | airai
# Processing Record 28 of Set 4 | nador
# Processing Record 29 of Set 4 | mogadishu
# Processing Record 30 of Set 4 | hilo
# Processing Record 31 of Set 4 | marystown
# Processing Record 32 of Set 4 | antalaha
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | farap
# Processing Record 36 of Set 4 | hilton head island
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | abu dhabi
# Processing Record 39 of Set 4 | sehithwa
# Processing Record 40 of Set 4 | sinnamary
# Processing Record 41 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 4 | barranca
# Processing Record 43 of Set 4 | havre-saint-pierre
# Processing Record 44 of Set 4 | cap malheureux
# Processing Record 45 of Set 4 | cidreira
# Processing Record 46 of Set 4 | batsfjord
# Processing Record 47 of Set 4 | rocha
# Processing Record 48 of Set 4 | sosnovo-ozerskoye
# Processing Record 49 of Set 4 | lukuledi
# Processing Record 50 of Set 4 | orlik
# Processing Record 0 of Set 5 | cayenne
# Processing Record 1 of Set 5 | caluquembe
# Processing Record 2 of Set 5 | carlagan
# Processing Record 3 of Set 5 | lata
# Processing Record 4 of Set 5 | shitanjing
# Processing Record 5 of Set 5 | menomonie
# Processing Record 6 of Set 5 | conceicao da barra
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | dukat
# Processing Record 9 of Set 5 | mazatlan
# Processing Record 10 of Set 5 | areosa
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | chama
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | tilaran
# Processing Record 15 of Set 5 | mecca
# Processing Record 16 of Set 5 | rawson
# Processing Record 17 of Set 5 | mackay
# Processing Record 18 of Set 5 | melfi
# Processing Record 19 of Set 5 | murgab
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | maldonado
# Processing Record 24 of Set 5 | batemans bay
# Processing Record 25 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 5 | katsuura
# Processing Record 27 of Set 5 | kericho
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | mimoso do sul
# Processing Record 30 of Set 5 | tarko-sale
# Processing Record 31 of Set 5 | shizuishan
# Processing Record 32 of Set 5 | nha trang
# Processing Record 33 of Set 5 | leh
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 36 of Set 5 | ballina
# Processing Record 37 of Set 5 | hualmay
# Processing Record 38 of Set 5 | juba
# Processing Record 39 of Set 5 | buala
# Processing Record 40 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 5 | saskylakh
# Processing Record 42 of Set 5 | butaritari
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | camacha
# Processing Record 45 of Set 5 | dhidhdhoo
# Processing Record 46 of Set 5 | dunedin
# Processing Record 47 of Set 5 | roebourne
# Processing Record 48 of Set 5 | castro
# Processing Record 49 of Set 5 | vilhena
# Processing Record 50 of Set 5 | gualaquiza
# Processing Record 0 of Set 6 | los altos
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | markala
# Processing Record 3 of Set 6 | broken hill
# Processing Record 4 of Set 6 | kayerkan
# Processing Record 5 of Set 6 | maine-soroa
# Processing Record 6 of Set 6 | sibolga
# Processing Record 7 of Set 6 | svetlyy
# Processing Record 8 of Set 6 | kokopo
# Processing Record 9 of Set 6 | banes
# Processing Record 10 of Set 6 | koumac
# Processing Record 11 of Set 6 | placido de castro
# Processing Record 12 of Set 6 | aksay
# Processing Record 13 of Set 6 | ngunguru
# Processing Record 14 of Set 6 | abu samrah
# Processing Record 15 of Set 6 | olafsvik
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | peniche
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | bobcaygeon
# Processing Record 20 of Set 6 | sano
# Processing Record 21 of Set 6 | berlevag
# Processing Record 22 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 6 | ancud
# Processing Record 24 of Set 6 | sirpur
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | mindelo
# Processing Record 27 of Set 6 | svetlogorsk
# Processing Record 28 of Set 6 | nikolskoye
# Processing Record 29 of Set 6 | assinovskaya
# Processing Record 30 of Set 6 | san jose
# Processing Record 31 of Set 6 | pangody
# Processing Record 32 of Set 6 | kizukuri
# Processing Record 33 of Set 6 | mariakani
# Processing Record 34 of Set 6 | kasangulu
# Processing Record 35 of Set 6 | ulaangom
# Processing Record 36 of Set 6 | bethel
# Processing Record 37 of Set 6 | san francisco
# Processing Record 38 of Set 6 | dubai
# Processing Record 39 of Set 6 | wuwei
# Processing Record 40 of Set 6 | faya
# Processing Record 41 of Set 6 | asau
# Processing Record 42 of Set 6 | port lincoln
# Processing Record 43 of Set 6 | guelengdeng
# City not found. Skipping...
# Processing Record 44 of Set 6 | fereydun kenar
# Processing Record 45 of Set 6 | mineiros
# Processing Record 46 of Set 6 | camana
# Processing Record 47 of Set 6 | merauke
# Processing Record 48 of Set 6 | praia
# Processing Record 49 of Set 6 | my tho
# Processing Record 50 of Set 6 | mountain home
# Processing Record 0 of Set 7 | korla
# Processing Record 1 of Set 7 | oktyabrskiy
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | boffa
# Processing Record 4 of Set 7 | calabozo
# Processing Record 5 of Set 7 | aleksandrov gay
# Processing Record 6 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 7 | ramsar
# Processing Record 8 of Set 7 | waingapu
# Processing Record 9 of Set 7 | clyde river
# Processing Record 10 of Set 7 | vuktyl
# Processing Record 11 of Set 7 | cabedelo
# Processing Record 12 of Set 7 | lorengau
# Processing Record 13 of Set 7 | strazske
# Processing Record 14 of Set 7 | faurei
# Processing Record 15 of Set 7 | srandakan
# Processing Record 16 of Set 7 | bima
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 7 | aripuana
# Processing Record 20 of Set 7 | doka
# Processing Record 21 of Set 7 | lubao
# Processing Record 22 of Set 7 | broome
# Processing Record 23 of Set 7 | marsabit
# Processing Record 24 of Set 7 | ust-omchug
# Processing Record 25 of Set 7 | salalah
# Processing Record 26 of Set 7 | mandan
# Processing Record 27 of Set 7 | mashpee
# Processing Record 28 of Set 7 | neuquen
# Processing Record 29 of Set 7 | brigantine
# Processing Record 30 of Set 7 | bay roberts
# Processing Record 31 of Set 7 | sabzevar
# Processing Record 32 of Set 7 | buseresere
# Processing Record 33 of Set 7 | riyadh
# Processing Record 34 of Set 7 | chala
# Processing Record 35 of Set 7 | atikokan
# Processing Record 36 of Set 7 | visnes
# Processing Record 37 of Set 7 | wanning
# Processing Record 38 of Set 7 | biak
# Processing Record 39 of Set 7 | ambanja
# Processing Record 40 of Set 7 | constitucion
# Processing Record 41 of Set 7 | mount isa
# Processing Record 42 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 7 | ambulu
# Processing Record 44 of Set 7 | ulladulla
# Processing Record 45 of Set 7 | olga
# Processing Record 46 of Set 7 | mao
# Processing Record 47 of Set 7 | khor
# Processing Record 48 of Set 7 | najran
# Processing Record 49 of Set 7 | strangnas
# Processing Record 50 of Set 7 | kirakira
# Processing Record 0 of Set 8 | bereda
# Processing Record 1 of Set 8 | vicuna
# Processing Record 2 of Set 8 | chikola
# Processing Record 3 of Set 8 | luderitz
# Processing Record 4 of Set 8 | landsberg
# Processing Record 5 of Set 8 | ambilobe
# Processing Record 6 of Set 8 | amahai
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | oranjemund
# Processing Record 9 of Set 8 | faanui
# Processing Record 10 of Set 8 | la ronge
# Processing Record 11 of Set 8 | taywarah
# Processing Record 12 of Set 8 | maningrida
# Processing Record 13 of Set 8 | miandrivazo
# Processing Record 14 of Set 8 | aksarka
# Processing Record 15 of Set 8 | viedma
# Processing Record 16 of Set 8 | north platte
# Processing Record 17 of Set 8 | sabinas
# Processing Record 18 of Set 8 | matata
# Processing Record 19 of Set 8 | adrar
# Processing Record 20 of Set 8 | bandarbeyla
# Processing Record 21 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 8 | kem
# Processing Record 23 of Set 8 | narsaq
# Processing Record 24 of Set 8 | lake cowichan
# Processing Record 25 of Set 8 | kangaatsiaq
# Processing Record 26 of Set 8 | americus
# Processing Record 27 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 8 | kastamonu
# Processing Record 29 of Set 8 | sandwick
# Processing Record 30 of Set 8 | taltal
# Processing Record 31 of Set 8 | byron bay
# Processing Record 32 of Set 8 | alberton
# Processing Record 33 of Set 8 | kaoma
# Processing Record 34 of Set 8 | tinskoy
# Processing Record 35 of Set 8 | olinda
# Processing Record 36 of Set 8 | skibbereen
# Processing Record 37 of Set 8 | nago
# Processing Record 38 of Set 8 | tongling
# Processing Record 39 of Set 8 | ketchikan
# Processing Record 40 of Set 8 | santa cruz
# Processing Record 41 of Set 8 | alakurtti
# Processing Record 42 of Set 8 | sapozhok
# Processing Record 43 of Set 8 | moose factory
# Processing Record 44 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 8 | araceli
# Processing Record 46 of Set 8 | belyy yar
# Processing Record 47 of Set 8 | frederico westphalen
# Processing Record 48 of Set 8 | mukhtolovo
# Processing Record 49 of Set 8 | nuuk
# Processing Record 50 of Set 8 | asmar
# Processing Record 0 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 1 of Set 9 | alice springs
# Processing Record 2 of Set 9 | arcos
# Processing Record 3 of Set 9 | venice
# Processing Record 4 of Set 9 | phuket
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | ellisras
# Processing Record 7 of Set 9 | norman wells
# Processing Record 8 of Set 9 | fairbanks
# Processing Record 9 of Set 9 | altea
# Processing Record 10 of Set 9 | sesheke
# Processing Record 11 of Set 9 | sioux lookout
# Processing Record 12 of Set 9 | tostamaa
# City not found. Skipping...
# Processing Record 13 of Set 9 | matagami
# Processing Record 14 of Set 9 | disna
# Processing Record 15 of Set 9 | jalu
# Processing Record 16 of Set 9 | estevan
# Processing Record 17 of Set 9 | gizo
# Processing Record 18 of Set 9 | cockburn town
# Processing Record 19 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 9 | college
# Processing Record 21 of Set 9 | elko
# Processing Record 22 of Set 9 | cananeia
# Processing Record 23 of Set 9 | maryville
# Processing Record 24 of Set 9 | dromolaxia
# Processing Record 25 of Set 9 | iki-burul
# Processing Record 26 of Set 9 | port-gentil
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | manggar
# Processing Record 29 of Set 9 | mahibadhoo
# Processing Record 30 of Set 9 | makaha
# Processing Record 31 of Set 9 | mahon
# Processing Record 32 of Set 9 | totolapa
# Processing Record 33 of Set 9 | zhaotong
# Processing Record 34 of Set 9 | santa rosa
# Processing Record 35 of Set 9 | barentu
# Processing Record 36 of Set 9 | isangel
# Processing Record 37 of Set 9 | ilebo
# Processing Record 38 of Set 9 | nantucket
# Processing Record 39 of Set 9 | alyangula
# Processing Record 40 of Set 9 | taranagar
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | mingguang
# Processing Record 43 of Set 9 | bethal
# Processing Record 44 of Set 9 | burnie
# Processing Record 45 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 9 | metkovic
# Processing Record 47 of Set 9 | yokadouma
# Processing Record 48 of Set 9 | naze
# Processing Record 49 of Set 9 | balkhash
# Processing Record 50 of Set 9 | dillon
# Processing Record 0 of Set 10 | kirishi
# Processing Record 1 of Set 10 | gua musang
# Processing Record 2 of Set 10 | bulgan
# Processing Record 3 of Set 10 | ekhabi
# Processing Record 4 of Set 10 | lompoc
# Processing Record 5 of Set 10 | rottingdean
# Processing Record 6 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 7 of Set 10 | capreol
# Processing Record 8 of Set 10 | aklavik
# Processing Record 9 of Set 10 | quatre cocos
# Processing Record 10 of Set 10 | bourail
# Processing Record 11 of Set 10 | manitouwadge
# Processing Record 12 of Set 10 | ishigaki
# Processing Record 13 of Set 10 | itapissuma
# Processing Record 14 of Set 10 | bundaberg
# Processing Record 15 of Set 10 | dargaville
# Processing Record 16 of Set 10 | tura
# Processing Record 17 of Set 10 | buribay
# Processing Record 18 of Set 10 | sapa
# Processing Record 19 of Set 10 | chaman
# Processing Record 20 of Set 10 | gondanglegi
# Processing Record 21 of Set 10 | soyo
# Processing Record 22 of Set 10 | high level
# Processing Record 23 of Set 10 | rabak
# Processing Record 24 of Set 10 | wuda
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | robe
# Processing Record 27 of Set 10 | gorontalo
# Processing Record 28 of Set 10 | det udom
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | uvat
# Processing Record 31 of Set 10 | yerofey pavlovich
# Processing Record 32 of Set 10 | ambon
# Processing Record 33 of Set 10 | angra
# City not found. Skipping...
# Processing Record 34 of Set 10 | limenaria
# Processing Record 35 of Set 10 | la paz
# Processing Record 36 of Set 10 | bonavista
# Processing Record 37 of Set 10 | pampilhosa
# Processing Record 38 of Set 10 | cochrane
# Processing Record 39 of Set 10 | orange cove
# Processing Record 40 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 10 | kibuye
# Processing Record 42 of Set 10 | sfantu gheorghe
# Processing Record 43 of Set 10 | kiknur
# Processing Record 44 of Set 10 | aranos
# Processing Record 45 of Set 10 | dingle
# Processing Record 46 of Set 10 | antioquia
# Processing Record 47 of Set 10 | mehamn
# Processing Record 48 of Set 10 | pietersburg
# Processing Record 49 of Set 10 | arlit
# Processing Record 50 of Set 10 | maku
# Processing Record 0 of Set 11 | maltahohe
# Processing Record 1 of Set 11 | aksha
# Processing Record 2 of Set 11 | ruston
# Processing Record 3 of Set 11 | humberto de campos
# Processing Record 4 of Set 11 | idukki
# Processing Record 5 of Set 11 | hailin
# Processing Record 6 of Set 11 | mumbwa
# Processing Record 7 of Set 11 | napierville
# Processing Record 8 of Set 11 | upington
# Processing Record 9 of Set 11 | krasne
# Processing Record 10 of Set 11 | zhucheng
# Processing Record 11 of Set 11 | ponta delgada
# Processing Record 12 of Set 11 | kalianget
# Processing Record 13 of Set 11 | qaqortoq
# Processing Record 14 of Set 11 | tezu
# Processing Record 15 of Set 11 | ryotsu
# Processing Record 16 of Set 11 | rio tercero
# Processing Record 17 of Set 11 | humaita
# Processing Record 18 of Set 11 | semirom
# Processing Record 19 of Set 11 | yudong
# Processing Record 20 of Set 11 | debre tabor
# Processing Record 21 of Set 11 | mayor pablo lagerenza
# Processing Record 22 of Set 11 | mitu
# Processing Record 23 of Set 11 | shenkursk
# Processing Record 24 of Set 11 | sao joao do piaui
# Processing Record 25 of Set 11 | simbahan
# Processing Record 26 of Set 11 | antigonish
# Processing Record 27 of Set 11 | llanes
# Processing Record 28 of Set 11 | atambua
# Processing Record 29 of Set 11 | potgietersrus
# City not found. Skipping...
# Processing Record 30 of Set 11 | krasnoarmeyskoye
# Processing Record 31 of Set 11 | vanavara
# Processing Record 32 of Set 11 | arinos
# Processing Record 33 of Set 11 | mayo
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | paris
# Processing Record 36 of Set 11 | nouadhibou
# Processing Record 37 of Set 11 | haines junction
# Processing Record 38 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 11 | bilma
# Processing Record 40 of Set 11 | teya
# Processing Record 41 of Set 11 | huarmey
# Processing Record 42 of Set 11 | sao francisco
# Processing Record 43 of Set 11 | iringa
# Processing Record 44 of Set 11 | sao filipe
# Processing Record 45 of Set 11 | sao jose da coroa grande
# Processing Record 46 of Set 11 | nuevo laredo
# Processing Record 47 of Set 11 | evora
# Processing Record 48 of Set 11 | taoudenni
# Processing Record 49 of Set 11 | schweinfurt
# Processing Record 50 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 0 of Set 12 | shenjiamen
# Processing Record 1 of Set 12 | abnub
# Processing Record 2 of Set 12 | buenos aires
# Processing Record 3 of Set 12 | bezlyudivka
# Processing Record 4 of Set 12 | shingu
# Processing Record 5 of Set 12 | timra
# Processing Record 6 of Set 12 | seoul
# Processing Record 7 of Set 12 | barrancas
# Processing Record 8 of Set 12 | nieuw amsterdam
# Processing Record 9 of Set 12 | aras
# Processing Record 10 of Set 12 | sambava
# Processing Record 11 of Set 12 | cooma
# Processing Record 12 of Set 12 | xinmin
# Processing Record 13 of Set 12 | nome
# Processing Record 14 of Set 12 | dieppe bay
# City not found. Skipping...
# Processing Record 15 of Set 12 | young
# Processing Record 16 of Set 12 | lavrentiya
# Processing Record 17 of Set 12 | ruteng
# Processing Record 18 of Set 12 | petauke
# Processing Record 19 of Set 12 | bulaevo
# Processing Record 20 of Set 12 | kashary
# Processing Record 21 of Set 12 | saint-francois
# Processing Record 22 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 12 | amiens
# Processing Record 24 of Set 12 | okha
# Processing Record 25 of Set 12 | wageningen
# Processing Record 26 of Set 12 | port hedland
# Processing Record 27 of Set 12 | qujing
# Processing Record 28 of Set 12 | haimen
# Processing Record 29 of Set 12 | shimoda
# Processing Record 30 of Set 12 | mongo
# Processing Record 31 of Set 12 | anadyr
# Processing Record 32 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 12 | whitehorse
# Processing Record 35 of Set 12 | deputatskiy
# Processing Record 36 of Set 12 | gladstone
# Processing Record 37 of Set 12 | veraval
# Processing Record 38 of Set 12 | itamarandiba
# Processing Record 39 of Set 12 | balsas
# Processing Record 40 of Set 12 | luba
# Processing Record 41 of Set 12 | umm kaddadah
# Processing Record 42 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 43 of Set 12 | sur
# Processing Record 44 of Set 12 | cervo
# Processing Record 45 of Set 12 | esso
# Processing Record 46 of Set 12 | sassandra
# Processing Record 47 of Set 12 | puro
# Processing Record 48 of Set 12 | moyale
# Processing Record 49 of Set 12 | yaan
# Processing Record 50 of Set 12 | port hardy
# Processing Record 0 of Set 13 | maniitsoq
# Processing Record 1 of Set 13 | agde
# Processing Record 2 of Set 13 | san quintin
# Processing Record 3 of Set 13 | sao teotonio
# Processing Record 4 of Set 13 | safford
# Processing Record 5 of Set 13 | dharapuram
# Processing Record 6 of Set 13 | longyearbyen
# Processing Record 7 of Set 13 | bubaque
# Processing Record 8 of Set 13 | cherskiy
# Processing Record 9 of Set 13 | auki
# Processing Record 10 of Set 13 | leeuwarden
# Processing Record 11 of Set 13 | jinka
# Processing Record 12 of Set 13 | koslan
# Processing Record 13 of Set 13 | ostersund
# Processing Record 14 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 15 of Set 13 | kabompo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(citydata)
city_df = city_df [["City","Cloudiness","Humidity","Latitude","Max Temp","Wind Speed"]]
city_df
# Out:
#            City  Cloudiness  Humidity  Latitude  Max Temp  Wind Speed
# 0       okhotsk          68        77     59.38     21.20        5.66
# 1     hithadhoo          61        72     -0.60     84.02        9.73
# 2        avarua         100        83    -21.21     82.40        8.05
# 3     stromness         100        93     58.97     44.60       16.11
# 4     paramonga          44        91    -10.67     71.42       13.56
# ..          ...         ...       ...       ...       ...         ...
# 576  leeuwarden          26        55     53.20     37.40        5.82
# 577       jinka          30        72      5.65     69.80        4.34
# 578      koslan           0        93     63.46     15.08        6.38
# 579   ostersund         100        59     63.18     35.60       18.34
# 580     kabompo          31        98    -13.59     59.72        4.47
#
# [581 rows x 6 columns]

# %%
city_df['City'] = city_df['City'].str.capitalize() 
city_df.head()
# Out:
#         City  Cloudiness  Humidity  Latitude  Max Temp  Wind Speed
# 0    Okhotsk          68        77     59.38     21.20        5.66
# 1  Hithadhoo          61        72     -0.60     84.02        9.73
# 2     Avarua         100        83    -21.21     82.40        8.05
# 3  Stromness         100        93     58.97     44.60       16.11
# 4  Paramonga          44        91    -10.67     71.42       13.56

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
city_df.plot(x = 'Latitude',y = 'Max Temp',kind ='scatter',title="Latitude vs. Max Temperature",grid = True)
plt.savefig("Max_Temp_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
city_df.plot(x = 'Latitude',y = 'Humidity',kind ='scatter',title="Latitude vs. Humidity",grid = True)
plt.savefig("Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
city_df.plot(x = 'Latitude',y = 'Cloudiness',kind ='scatter',title="Latitude vs. Cloudiness",grid = True)
plt.savefig("Cloudiness_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
city_df.plot(x = 'Latitude',y = 'Wind Speed',kind ='scatter',title="Latitude vs. Wind Speed",grid = True)
plt.savefig("Wind Speed_vs_Latitude.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = city_df.loc[pd.to_numeric(city_df["Latitude"]).astype(float) > 0, :]
southern_df = city_df.loc[pd.to_numeric(city_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, temperature decreases as you move away from the equator.")
plt.savefig("NH_Max Temp_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = -1.11x + 91.37
# The r-squared is: -0.8940255629661287
# The regression displays a negative correlation.
# In the nothern hemisphere, temperature decreases as you move away from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, temperature increases as you get closer to the equator.")
plt.savefig("SH_Max Temp_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = 0.41x + 80.92
# The r-squared is: 0.476847458428884
# The regression displays a positive correlation.
# In the southern hemisphere, temperature increases as you get closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There is not much correlation among data points.")
plt.savefig("NH_Humidity_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = 0.26x + 59.63
# The r-squared is: 0.22944960081521842
# There is not much correlation among data points.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There is not much correlation among data points.")
plt.savefig("SH_Humidity_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = 0.37x + 83.33
# The r-squared is: 0.25673627147496225
# There is not much correlation among data points.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There is not much correlation among data points.")
plt.savefig("NH_Cloudiness_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = 0.46x + 34.41
# The r-squared is: 0.21946069357983689
# There is not much correlation among data points.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There is not much correlation among data points.")
plt.savefig("SH_Cloudiness_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = 0.42x + 65.18
# The r-squared is: 0.14366738715999702
# There is not much correlation among data points.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There is not much correlation among data points.")
plt.savefig("NH_Wind Speed_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = 0.08x + 6.27
# The r-squared is: 0.24038477598939997
# There is not much correlation among data points.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There is not much correlation among data points.")
plt.savefig("SH_Wind Speed_vs_Latitude_LR.png")
plt.show()
# Out:
# Regression line equation is: y = -0.16x + 3.79
# The r-squared is: -0.39891649044218663
# There is not much correlation among data points.
